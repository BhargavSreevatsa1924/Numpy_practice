# %% [markdown]
# Use the random.normal() method to get a Normal Data Distribution.
#
# It has three parameters:
#
# loc - (Mean) where the peak of the bell exists.
#
# scale - (Standard Deviation) how flat the graph distribution should be.
#
# size - The shape of the returned array.

# %%
from numpy import random
# a random normal distribution of size 2x3:

x = random.normal(size=(3,5))
print(x)
# Out:
# [[-0.0391079   0.87333662 -0.13432294 -0.84151857  0.04481524]
#  [-0.0220699   2.00637874 -1.76198506  0.0691159  -0.25514223]
#  [-1.64959101  0.05214367  1.82647655  0.26198101  0.43785362]]

# %%
x = random.normal(loc=1, scale=2,size=(2,3))
print(x)
# Out:
# [[-2.91758905  1.36350479  5.37132604]
#  [ 0.84267972  3.20997787  0.93545649]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.displot(random.normal(size=1000),kind="kde")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('normal distribution visualisation')
plt.show()

# %% [markdown]
# # The curve of a Normal Distribution is also known as the Bell Curve because of the bell-shaped curve.
